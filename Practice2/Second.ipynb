# %%
import numpy as np
a= np.random.randint(1,100,30).reshape(6,5)
print(a)
# Out:
# [[20 35 66 82 16]
#  [35 55 98 89 58]
#  [16 85  8 80 83]
#  [94 67 21 78 28]
#  [51 59 44 98 81]
#  [68  1 90 29 74]]

# %%
#find the greater number than 50

a[a>50]
# Out:
# array([66, 82, 55, 98, 89, 58, 85, 80, 83, 94, 67, 78, 51, 59, 98, 81, 68,
#        90, 74])

# %%
#fund greater than 60 and even

a[(a>60) & (a%2==0)]
# Out:
# array([66, 82, 98, 80, 94, 78, 98, 68, 90, 74])

# %%
#broadxasting

# %%
a1= np.arange(6).reshape(3,2)
a2= np.arange(3).reshape(3,1)
print(a1)
print(a2)
# Out:
# [[0 1]
#  [2 3]
#  [4 5]]
# [[0]
#  [1]
#  [2]]

# %%
print(a1+a2)
# Out:
# [[0 1]
#  [3 4]
#  [6 7]]

# %%
#summation
a= np.arange(10)
print(a1)
# Out:
# [[0 1]
#  [2 3]
#  [4 5]]

# %%
np.sum(a1)
# Out:
# 15

# %%
#sigmoid
def sigmoid(array):
    return (1+1/np.exp(-(array)))

a=np.arange(20)
sigmoid(a)
# Out:
# array([2.00000000e+00, 3.71828183e+00, 8.38905610e+00, 2.10855369e+01,
#        5.55981500e+01, 1.49413159e+02, 4.04428793e+02, 1.09763316e+03,
#        2.98195799e+03, 8.10408393e+03, 2.20274658e+04, 5.98751417e+04,
#        1.62755791e+05, 4.42414392e+05, 1.20260528e+06, 3.26901837e+06,
#        8.88611152e+06, 2.41549538e+07, 6.56599701e+07, 1.78482302e+08])

# %%
#mean squaare error


actual = np.random.randint(1,50,25)
predicted=np.random.randint(1,50,25)
def mse(actul,predicted):
    return (np.mean(actual-predicted)**2)
    

mse(actual,predicted)
# Out:
# 13.5424

# %%
#missing values
a=np.array([1,2,3,np.nan,5])
print(a)
# Out:
# [ 1.  2.  3. nan  5.]

# %%
np.isnan(a)
# Out:
# array([False, False, False,  True, False])

# %%
#graph plotting
# x=y
import matplotlib.pyplot as plt
x=np.linspace(-10,10,10)
y=x
plt.plot(x,y)

# %%
#y=x^2
import matplotlib.pyplot as plt
x=np.linspace(-10,10,10)
y=x**2
plt.plot(x,y)

# %%
#y=sin(X)
import matplotlib.pyplot as plt
x=np.linspace(-10,10,10)
y=np.sin(x)
plt.plot(x,y)

# %%
#y=xlog(x)
import matplotlib.pyplot as plt
x=np.linspace(-10,10,10)
y=x * np.log(x)
plt.plot(x,y)
# Out:
# C:\Users\Md Saiful Islam\AppData\Local\Temp\ipykernel_20696\2404205550.py:4: RuntimeWarning: invalid value encountered in log
#   y=x * np.log(x)

# %%
#y=cos(X)
import matplotlib.pyplot as plt
x=np.linspace(-10,10,10)
y=np.cos(x)
plt.plot(x,y)

# %%
#y=tan(X)
import matplotlib.pyplot as plt
x=np.linspace(-10,10,10)
y=np.tan(x)
plt.plot(x,y)

# %%
#y=x^3
import matplotlib.pyplot as plt
x=np.linspace(-10,10,10)
y=-x**3
plt.plot(x,y)

# %%
#y=x^3+x^2+10
import matplotlib.pyplot as plt
x=np.linspace(-10,10,10)
y=(x**3) + (x**2) + 100
plt.plot(x,y)

# %%
#y=tan(X)
import matplotlib.pyplot as plt
x=np.linspace(-10,10,10)
y=np.linspace(-3,3,10)
z=np.linspace(-3,3,4)
plt.plot(x,y,z)
plt.plot(y,x)

# %%
#y=tan(X)
import matplotlib.pyplot as plt
x=np.linspace(-10,10,10)
y=10*x
plt.plot(x,y)
